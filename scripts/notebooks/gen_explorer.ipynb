# %%
from random import random
import json
with open("/w/exp/mkt/generated/gen.jsonl", "r") as f:
    gen_examples = [json.loads(line) for line in f]

# %%
example = gen_examples[int(random()*1000)]
print(example['input'])
for label in example['labels']:
    print("-"*70+f"Temperature={example['temperature']}"+"-"*70)
    print(label)
# Out:
# 다음의 상품을 홍보하는 창의적인 마케팅 문구를 작성해 보세요.
# [회사]
# [카테고리]
# [분류]
# [상품명] 웨이브
# [마케팅 문구]
# ----------------------------------------------------------------------Temperature=0.38237462494534435----------------------------------------------------------------------
# 내가 원하는 콘텐츠가 다 있는 OTT 플랫폼
# ----------------------------------------------------------------------Temperature=0.38237462494534435----------------------------------------------------------------------
# 세상의 모든 즐거움이 한 곳에 모여 있다면?
# ----------------------------------------------------------------------Temperature=0.38237462494534435----------------------------------------------------------------------
# 나는 너의 모든 것을 사랑했다. 하지만, 너의 그 말투만은 용서할 수 없었다
# ----------------------------------------------------------------------Temperature=0.38237462494534435----------------------------------------------------------------------
# 드라마, 예능, 영화까지 보고 싶은 건 많은데 볼 시간이 없다면?
# ...
